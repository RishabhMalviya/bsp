# %%
from pprint import pprint

# %%
from shimmy.registration import DM_CONTROL_SUITE_ENVS

pprint([env_info_tuple for env_info_tuple in DM_CONTROL_SUITE_ENVS if env_info_tuple[0] == 'humanoid'])
# Out:
# [('humanoid', 'stand'),
#  ('humanoid', 'walk'),
#  ('humanoid', 'run'),
#  ('humanoid', 'run_pure_state')]

# %%
import gymnasium as gym

# %%
env = gym.make('dm_control/humanoid-stand-v0')
env = gym.wrappers.FlattenObservation(env)
# env = gym.wrappers.TimeLimit(env, max_episode_steps=1000)

print(env.observation_space.shape[0])
print(env.action_space.shape[0])
# Out:
# ---------------------------------------------------------------------------
# NamespaceNotFound                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 env = gym.make('dm_control/humanoid-stand-v0')
#       2 env = gym.wrappers.FlattenObservation(env)
#       3 # env = gym.wrappers.TimeLimit(env, max_episode_steps=1000)
#       4
#
# File ~/learNiNG/cs224r/project/bsp/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py:682, in make(id, max_episode_steps, disable_env_checker, **kwargs)
#     679     assert isinstance(id, str)
#     681     # The environment name can include an unloaded module in "module:env_name" style
# --> 682     env_spec = _find_spec(id)
#     684 assert isinstance(env_spec, EnvSpec)
#     686 # Update the env spec kwargs with the `make` kwargs
#
# File ~/learNiNG/cs224r/project/bsp/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py:527, in _find_spec(env_id)
#     521     logger.warn(
#     522         f"Using the latest versioned environment `{new_env_id}` "
#     523         f"instead of the unversioned environment `{env_name}`."
#     524     )
#     526 if env_spec is None:
# --> 527     _check_version_exists(ns, name, version)
#     528     raise error.Error(
#     529         f"No registered env with id: {env_name}. Did you register it, or import the package that registers it? Use `gymnasium.pprint_registry()` to see all of the registered environments."
#     530     )
#     532 return env_spec
#
# File ~/learNiNG/cs224r/project/bsp/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py:391, in _check_version_exists(ns, name, version)
#     388 if get_env_id(ns, name, version) in registry:
#     389     return
# --> 391 _check_name_exists(ns, name)
#     392 if version is None:
#     393     return
#
# File ~/learNiNG/cs224r/project/bsp/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py:354, in _check_name_exists(ns, name)
#     352 """Check if an env exists in a namespace. If it doesn't, print a helpful error message."""
#     353 # First check if the namespace exists
# --> 354 _check_namespace_exists(ns)
#     356 # Then check if the name exists
#     357 names: set[str] = {
#     358     env_spec.name for env_spec in registry.values() if env_spec.namespace == ns
#     359 }
#
# File ~/learNiNG/cs224r/project/bsp/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py:348, in _check_namespace_exists(ns)
#     345 else:
#     346     suggestion_msg = f"Have you installed the proper package for {ns}?"
# --> 348 raise error.NamespaceNotFound(f"Namespace {ns} not found. {suggestion_msg}")
#
# NamespaceNotFound: Namespace dm_control not found. Have you installed the proper package for dm_control?

# %%
env = gym.make('dm_control/humanoid-stand-v0')
env = gym.wrappers.FlattenObservation(env)

obs, info = env.reset(seed=423535)
done = False
timestep = 0
total_reward = 0
gamma = 0.99

while not done and timestep < 100_000:
    timestep += 1  # 1-indexed
    action = env.action_space.sample()
    obs, reward, terminated, truncated, info = env.step(action)
    total_reward = reward + gamma*total_reward

    done = terminated or truncated

    if timestep % 100 == 0:
        print(f'{timestep} time-steps completed')
        print(f'Current return: {total_reward}')
        print()
    
env.close()
# Out:
# 100 time-steps completed
# Current return: 1.057338349350019
#
# 200 time-steps completed
# Current return: 0.38702003153688
#
# 300 time-steps completed
# Current return: 0.14166184839964205
#
# 400 time-steps completed
# Current return: 0.05185283120255692
#
# 500 time-steps completed
# Current return: 0.018979813224776446
#
# 600 time-steps completed
# Current return: 0.006947225474216969
#
# 700 time-steps completed
# Current return: 0.0025429092825046437
#
# 800 time-steps completed
# Current return: 0.0009307873034526224
#
# 900 time-steps completed
# Current return: 0.00034069913480786623
#
# 1000 time-steps completed
# Current return: 0.00012470807690556637
